# %% [markdown]
# # JusticeEngine-01: TRL GRPO Training Loop
#
# This notebook trains an LLM using **Unsloth** and **TRL GRPOTrainer** inside the `JudicialEnv` using Reinforcement Learning with Verifiable Rewards (RLVR).
#
# **Hardware requirement:** T4 GPU (Google Colab free tier is perfectly fine).

# %%
# 1. Install Dependencies
# !pip install "unsloth[colab-new] @ git+https://github.com/unslothai/unsloth.git"
# !pip install --no-deps xformers trl peft accelerate bitsandbytes datasets

# %%
# 2. Clone the Repository to get the Environment and Data
# !git clone https://github.com/rishitaramola/judicial-reasoning-env.git
# %cd Judicial-Reasoning-RL-Environment

# %% [markdown]
# ### Run the Training Script
# The training script `train.py` is fully configured to patch Unsloth for fast RL, load the dataset from `data/cases.json`, and apply our custom reward functions (Logic, Accuracy, Format) by stepping through the `JudicialEnv`.

# %%
# 3. Execute the Training Loop
# !python train.py
